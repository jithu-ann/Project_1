# %%
import pandas as pd 
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st
import matplotlib.figure

# %%
#Path to our csv files
stock_data = Path("Resources/ETF_prices.csv")

#Reading csv files into pandas
stock_df = pd.read_csv(stock_data)
stock_df
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
#stock of fund symbol AAAU
stock_fund_df = stock_df[stock_df['fund_symbol']=='AAAU']
stock_fund_df
# Out:
#      fund_symbol  price_date   open   high    low  close  adj_close  volume
# 310         AAAU  2018-08-15  11.84  11.84  11.74  11.74      11.74   27300
# 311         AAAU  2018-08-16  11.78  11.80  11.74  11.74      11.74  428400
# 312         AAAU  2018-08-17  11.80  11.82  11.77  11.82      11.82   52400
# 313         AAAU  2018-08-20  11.88  11.91  11.85  11.90      11.90   28700
# 314         AAAU  2018-08-21  11.92  11.95  11.89  11.93      11.93   30600
# ...          ...         ...    ...    ...    ...    ...        ...     ...
# 1135        AAAU  2021-11-23  17.79  17.83  17.71  17.80      17.80  276600
# 1136        AAAU  2021-11-24  17.73  17.81  17.70  17.78      17.78  269900
# 1137        AAAU  2021-11-26  17.95  17.95  17.70  17.75      17.75  334600
# 1138        AAAU  2021-11-29  17.75  17.79  17.71  17.73      17.73  171900
# 1139        AAAU  2021-11-30  17.84  17.98  17.60  17.61      17.61  250700
#
# [830 rows x 8 columns]

# %%
#stock of the entire year of 2019,2020,2021
stock_all_2019_df = stock_df[stock_df['price_date'].between('2019-01-01','2019-12-31')]
stock_all_2020_df = stock_df[stock_df['price_date'].between('2020-01-01','2020-12-31')]
stock_all_2021_df = stock_df[stock_df['price_date'].between('2021-01-01','2021-12-31')]
stock_all_2021_df
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 80              AAA  2021-01-04  25.07  25.07  25.07  25.07      24.93    3700
# 81              AAA  2021-01-05  25.08  25.08  25.07  25.08      24.94    2300
# 82              AAA  2021-01-06  25.08  25.09  25.08  25.08      24.94     600
# 83              AAA  2021-01-07  25.08  25.08  25.08  25.08      24.94     400
# 84              AAA  2021-01-08  25.08  25.08  25.07  25.07      24.93    5300
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
#2019 data of AAAU
stock_2019_df = stock_fund_df[stock_fund_df['price_date'].between('2019-01-01','2019-12-31')]
stock_2019_df
# Out:
#     fund_symbol  price_date   open   high    low  close  adj_close  volume
# 405        AAAU  2019-01-02  12.87  13.11  12.80  13.05      13.05   46500
# 406        AAAU  2019-01-03  12.89  12.93  12.88  12.93      12.93   62600
# 407        AAAU  2019-01-04  12.83  12.85  12.76  12.84      12.84   12100
# 408        AAAU  2019-01-07  12.92  12.93  12.87  12.88      12.88   24500
# 409        AAAU  2019-01-08  12.78  12.85  12.78  12.85      12.85   17200
# ..          ...         ...    ...    ...    ...    ...        ...     ...
# 652        AAAU  2019-12-24  14.87  14.97  14.87  14.96      14.96   66400
# 653        AAAU  2019-12-26  15.06  15.10  15.04  15.07      15.07   42600
# 654        AAAU  2019-12-27  15.08  15.11  15.07  15.08      15.08   64600
# 655        AAAU  2019-12-30  15.11  15.13  15.11  15.11      15.11   93400
# 410        AAAU  2019-01-09  12.89  12.92  12.89  12.92      12.92   11600
# 411        AAAU  2019-01-10  12.90  12.91  12.86  12.86      12.86  536200
# 412        AAAU  2019-01-11  12.88  12.90  12.87  12.87      12.87   15900
# 413        AAAU  2019-01-14  12.91  12.91  12.89  12.91      12.91    4300
# 414        AAAU  2019-01-15  12.93  12.93  12.86  12.88      12.88  137900
# 415        AAAU  2019-01-16  12.91  12.94  12.91  12.93      12.93  163700
# ...

# %%
#Plot of the closing price in jan 2019
stock_plot = plt.plot(jan_2019_df['price_date'],jan_2019_df['close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing price of 2019')
plt.xticks(rotation="vertical")
plt.show()

# %%
#JAN 2020 data
jan_2020_df = stock_fund_df[stock_fund_df['price_date'].between('2020-01-01','2020-01-31')]
jan_2020_df
# Out:
#     fund_symbol  price_date   open   high    low  close  adj_close  volume
# 657        AAAU  2020-01-02  15.24  15.28  15.20  15.25      15.25   43100
# 658        AAAU  2020-01-03  15.45  15.49  15.42  15.45      15.45   53400
# 659        AAAU  2020-01-06  15.76  15.77  15.59  15.62      15.62   84100
# 660        AAAU  2020-01-07  15.64  15.70  15.64  15.68      15.68   35000
# 661        AAAU  2020-01-08  15.75  15.75  15.49  15.56      15.56  133600
# 662        AAAU  2020-01-09  15.48  15.51  15.41  15.47      15.47   24700
# 663        AAAU  2020-01-10  15.50  15.57  15.50  15.57      15.57   99100
# 664        AAAU  2020-01-13  15.50  15.51  15.26  15.45      15.45  161400
# 665        AAAU  2020-01-14  15.40  15.44  15.38  15.44      15.44   43500
# 666        AAAU  2020-01-15  15.50  15.54  15.45  15.52      15.52   41800
# 667        AAAU  2020-01-16  15.50  15.50  15.45  15.49      15.49   78200
# ...

# %%
#Plot of the closing price in jan 2020
stock_plot = plt.plot(jan_2020_df['price_date'],jan_2020_df['close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing price of 2020')
plt.xticks(rotation="vertical")
plt.show()

# %%
#jan 2021 data
jan_2021_df = stock_fund_df[stock_fund_df['price_date'].between('2021-01-01','2021-01-31')]
jan_2021_df
# Out:
#     fund_symbol  price_date   open   high    low  close  adj_close   volume
# 910        AAAU  2021-01-04  19.33  19.36  19.22  19.35      19.35   767800
# 911        AAAU  2021-01-05  19.42  19.44  19.31  19.41      19.41   607000
# 912        AAAU  2021-01-06  19.27  19.27  18.93  19.10      19.10  1425400
# 913        AAAU  2021-01-07  19.07  19.10  18.99  19.05      19.05   330200
# 914        AAAU  2021-01-08  18.78  18.78  18.22  18.41      18.41  1217300
# 915        AAAU  2021-01-11  18.27  18.44  18.27  18.38      18.38   441700
# 916        AAAU  2021-01-12  18.39  18.49  18.30  18.49      18.49   497800
# 917        AAAU  2021-01-13  18.45  18.52  18.39  18.40      18.40   665100
# 918        AAAU  2021-01-14  18.41  18.50  18.34  18.40      18.40   682400
# 919        AAAU  2021-01-15  18.36  18.37  18.16  18.18      18.18   333500
# 920        AAAU  2021-01-19  18.34  18.35  18.26  18.31      18.31  3583100
# ...

# %%
 #Plot of the closing price in jan 2021
stock_plot = plt.plot(jan_2021_df['price_date'],jan_2021_df['close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing price of 2021')
plt.xticks(rotation="vertical")
plt.show()

# %%
#Find mean, median, min and max closing price of fund symbol AAAU
stock_2019_fs_mean = stock_2019_df['close'].mean()
stock_2019_fs_min = stock_2019_df['close'].min()
stock_2019_fs_max = stock_2019_df['close'].max()
stock_2019_fs_median = stock_2019_df['close'].median()

stock_2020_fs_mean = stock_2020_df['close'].mean()
stock_2020_fs_min = stock_2020_df['close'].min()
stock_2020_fs_max = stock_2020_df['close'].max()
stock_2020_fs_median = stock_2020_df['close'].median()

stock_2021_fs_mean = stock_2021_df['close'].mean()
stock_2021_fs_min = stock_2021_df['close'].min()
stock_2021_fs_max = stock_2021_df['close'].max()
stock_2021_fs_median = stock_2021_df['close'].median()
#Create a dataframe with those  summary stats

stock_2021_summary_AAAU = pd.DataFrame.from_dict({"Mean": [stock_2019_fs_mean,stock_2020_fs_mean,stock_2021_fs_mean],
                                                "Median":[stock_2019_fs_median,stock_2020_fs_median,stock_2021_fs_median],
                                                "Minimum":[stock_2019_fs_min,stock_2020_fs_min, stock_2021_fs_min],
                                                "Maximum":[stock_2019_fs_max,stock_2020_fs_max,stock_2021_fs_max]}, orient = 'index')
stock_2021_summary_AAAU.rename(columns={0:"2019",1:"2020",2:"2021"})
# Out:
#               2019       2020      2021
# Mean     13.920317  17.681818  17.89887
# Median   14.070000  17.710000  17.84000
# Minimum  12.700000  14.650000  16.72000
# Maximum  15.520000  20.570000  19.41000

# %%
#Find mean, median, min and max closing price of the entire stock market
stock_2019_mean = stock_all_2019_df['close'].mean()
stock_2019_min = stock_all_2019_df['close'].min()
stock_2019_max = stock_all_2019_df['close'].max()
stock_2019_median = stock_all_2019_df['close'].median()

stock_2020_mean = stock_all_2020_df['close'].mean()
stock_2020_min = stock_all_2020_df['close'].min()
stock_2020_max = stock_all_2020_df['close'].max()
stock_2020_median = stock_all_2020_df['close'].median()

stock_2021_mean = stock_all_2021_df['close'].mean()
stock_2021_min = stock_all_2021_df['close'].min()
stock_2021_max = stock_all_2021_df['close'].max()
stock_2021_median = stock_all_2021_df['close'].median()
#Create a dataframe with those  summary stats

stock_2021_summary = pd.DataFrame.from_dict({"Mean": [stock_2019_mean,stock_2020_mean,stock_2021_mean],
                                                "Median":[stock_2019_median,stock_2020_median,stock_2021_median],
                                                "Minimum":[stock_2019_min,stock_2020_min, stock_2021_min],
                                                "Maximum":[stock_2019_max,stock_2020_max,stock_2021_max]}, orient = 'index')
stock_2021_summary.rename(columns={0:"2019",1:"2020",2:"2021"})
# Out:
#                 2019         2020        2021
# Mean       49.944355    42.915537   47.873116
# Median     32.230000    30.460000   34.790000
# Minimum     2.480000     0.680000    0.770000
# Maximum  5368.000000  2897.960000  883.180000
